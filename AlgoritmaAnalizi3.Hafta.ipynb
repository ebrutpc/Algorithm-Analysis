# %%
def Maxsubsum(n):
    maxSum = 0 
    for i in range(len(n)):
        for j in range(len(n)):
            thisSum=0
            for k in range(i,j+1):
                thisSum+=n[k]
            if(thisSum > maxSum):
                maxSum = thisSum
    return maxSum

# %%
def Maxsubsum2(n):
    maxSum=0
    for i in range(len(n)):
        thisSum=0
        for j in range (i,len(n)):
            thisSum+= n[j]
            if(thisSum > maxSum):
                maxSum = thisSum
    return maxSum

# %%
import time
def create_random_array(n):#n boyutlu dizi oluştur 
    import random
    arr=[]
    for i in range(n):
        arr.append(random.randint(-100,100))
        print(arr[i])
    return arr

# %%
dizi1=create_random_array(5)
dizi2=create_random_array(10)
dizi3=create_random_array(20)
dizi4=create_random_array(40)
dizi5=create_random_array(80)
dizi6=create_random_array(160)
dizi7=create_random_array(320)
dizi8=create_random_array(1000)
# Out:
# 93
# -41
# 96
# -83
# 31
# -100
# -23
# -7
# -63
# -42
# -14
# -96
# 1
# 52
# 3
# -91
# -79
# -42
# -98
# 79
# -58
# -3
# 3
# -57
# 41
# -38
# -65
# 70
# 76
# 46
# 39
# -21
# 69
# -38
# -37
# -55
# 80
# -67
# 44
# 32
# 65
# -69
# -36
# 69
# 62
# 73
# 74
# -40
# 37
# 84
# -16
# -14
# 75
# -16
# -58
# 96
# 26
# -79
# -58
# -18
# 6
# 59
# -59
# -98
# 51
# -66
# 88
# -63
# 60
# 33
# -94
# 4
# 8
# -20
# 29
# 79
# 84
# 46
# 98
# -9
# -72
# -47
# 95
# 80
# -18
# -97
# -17
# -21
# -23
# 97
# -1
# -65
# -37
# -47
# -59
# -45
# 48
# 22
# -34
# 48
# -51
# -55
# -7
# -27
# -56
# 44
# -6
# 5
# 67
# -85
# -24
# 99
# 4
# 26
# -84
# 96
# 92
# 75
# 87
# 96
# 13
# 35
# 22
# 17
# -94
# 10
# -81
# -35
# 2
# -18
# 89
# -98
# -27
# 17
# 11
# -8
# -70
# -8
# 64
# -39
# -48
# 86
# 26
# -23
# 69
# -75
# 42
# -71
# -83
# 7
# 98
# -27
# 90
# -24
# 49
# -28
# 24
# 14
# 13
# -69
# -30
# 40
# 37
# 32
# -3
# -15
# 39
# -76
# -68
# -65
# -93
# 51
# 76
# -42
# -81
# -74
# 95
# 40
# -85
# -82
# -66
# -83
# 31
# -28
# ...

# %%
t1=time.time()
print(Maxsubsum(dizi8))
t2=time.time()
t2-t1
# Out:
# 1380
# 10.434208393096924

# %%
t1=time.time()
print(Maxsubsum2(dizi8))
t2=time.time()
t2-t1
# Out:
# 1380
# 0.04203653335571289

# %%
t1=time.time()
print(Maxsubsum(dizi1))
t2=time.time()
t2-t1
# Out:
# 148
# 0.0010285377502441406

# %%
t1=time.time()
print(Maxsubsum2(dizi1))
t2=time.time()
t2-t1
# Out:
# 148
# 0.0

# %%
t1=time.time()
print(Maxsubsum(dizi2))
t2=time.time()
t2-t1
# Out:
# 56
# 0.0

# %%
t1=time.time()
print(Maxsubsum2(dizi2))
t2=time.time()
t2-t1
# Out:
# 56
# 0.0

# %%
t1=time.time()
print(Maxsubsum(dizi3))
t2=time.time()
t2-t1
# Out:
# 279
# 0.0

# %%
t1=time.time()
print(Maxsubsum2(dizi3))
t2=time.time()
t2-t1
# Out:
# 279
# 0.0

# %%
t1=time.time()
print(Maxsubsum(dizi4))
t2=time.time()
t2-t1
# Out:
# 501
# 0.00197601318359375

# %%
t1=time.time()
print(Maxsubsum2(dizi4))
t2=time.time()
t2-t1
# Out:
# 501
# 0.0

# %%
t1=time.time()
print(Maxsubsum(dizi5))
t2=time.time()
t2-t1
# Out:
# 579
# 0.0

# %%
t1=time.time()
print(Maxsubsum2(dizi5))
t2=time.time()
t2-t1
# Out:
# 579
# 0.0

# %%
t1=time.time()
print(Maxsubsum(dizi6))
t2=time.time()
t2-t1
# Out:
# 672
# 0.07393980026245117

# %%
t1=time.time()
print(Maxsubsum2(dizi6))
t2=time.time()
t2-t1
# Out:
# 672
# 0.000997781753540039

# %%
t1=time.time()
print(Maxsubsum(dizi7))
t2=time.time()
t2-t1
# Out:
# 970
# 0.32033348083496094

# %%
t1=time.time()
print(Maxsubsum2(dizi7))
t2=time.time()
t2-t1
# Out:
# 970
# 0.0039789676666259766
